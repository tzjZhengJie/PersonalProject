# %% [markdown]
# # Activity: Discover what is in your dataset

# %% [markdown]
# ## Introduction
#
# In this activity, you will discover characteristics of a dataset and use visualizations to analyze the data. This will develop and strengthen your skills in **exploratory data analysis (EDA)** and your knowledge of functions that allow you to explore and visualize data.
#
# EDA is an essential process in a data science workflow. As a data professional, you will need to conduct this process to better understand the data at hand and determine how it can be used to solve the problem you want to address. This activity will give you an opportunity to practice that process and prepare you for EDA in future projects.
#
# In this activity, you are a member of an analytics team that provides insights to an investing firm. To help them decide which companies to invest in next, the firm wants insights into **unicorn companies**–companies that are valued at over one billion dollars. The data you will use for this task provides information on over 1,000 unicorn companies, including their industry, country, year founded, and select investors. You will use this information to gain insights into how and when companies reach this prestigious milestone and to make recommentations for next steps to the investing firm.

# %% [markdown]
# ## Step 1: Imports

# %% [markdown]
# ### Import libraries and packages
#
# First, import relevant Python libraries and modules. Use the `pandas` library and the `matplotlib.pyplot` module.

# %%
# Import libraries and packages

### YOUR CODE HERE ###
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the dataset into a DataFrame
#
# The dataset provided is in the form of a csv file named `Unicorn_Companies.csv` and contains a subset of data on unicorn companies. As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA.

### YOUR CODE HERE ###
companies = pd.read_csv("Unicorn_Companies.csv")

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to what you learned about [loading data](https://www.coursera.org/learn/go-beyond-the-numbers-translate-data-into-insight/supplement/MdTG2/reference-guide-import-datasets-using-python) in Python.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the function in the `pandas` library that allows you to read data from a csv file and load the data into a DataFrame.
#
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `read_csv()` function from the `pandas` library.
#
# </details>

# %% [markdown]
# ## Step 2: Data exploration

# %% [markdown]
# ### Display the first 10 rows of the data
#
# Next, explore the dataset and answer questions to guide your exploration and analysis of the data. To begin, display the first 10 rows of the data to get an understanding of how the dataset is structured.

# %%
# Display the first 10 rows of the data

### YOUR CODE HERE ###
companies.head(10)
# Out:
#         Company Valuation Date Joined                             Industry  \
# 0     Bytedance     $180B      4/7/17              Artificial intelligence
# 1        SpaceX     $100B     12/1/12                                Other
# 2         SHEIN     $100B      7/3/18      E-commerce & direct-to-consumer
# 3        Stripe      $95B     1/23/14                              Fintech
# 4        Klarna      $46B    12/12/11                              Fintech
# 5         Canva      $40B      1/8/18         Internet software & services
# 6  Checkout.com      $40B      5/2/19                              Fintech
# 7     Instacart      $39B    12/30/14  Supply chain, logistics, & delivery
# 8     JUUL Labs      $38B    12/20/17                    Consumer & retail
# 9    Databricks      $38B      2/5/19          Data management & analytics
#
#             City  Country/Region      Continent  Year Founded Funding  \
# 0        Beijing           China           Asia          2012     $8B
# 1      Hawthorne   United States  North America          2002     $7B
# 2       Shenzhen           China           Asia          2008     $2B
# 3  San Francisco   United States  North America          2010     $2B
# 4      Stockholm          Sweden         Europe          2005     $4B
# 5    Surry Hills       Australia        Oceania          2012   $572M
# 6         London  United Kingdom         Europe          2012     $2B
# 7  San Francisco   United States  North America          2012     $3B
# 8  San Francisco   United States  North America          2015    $14B
# 9  San Francisco   United States  North America          2013     $3B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Institutional Venture Partners, Sequoia Capita...
# 5  Sequoia Capital China, Blackbird Ventures, Mat...
# 6  Tiger Global Management, Insight Partners, DST...
# 7  Khosla Ventures, Kleiner Perkins Caufield & By...
# 8                            Tiger Global Management
# 9  Andreessen Horowitz, New Enterprise Associates...

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to [the content about exploratory data analysis in Python](https://www.coursera.org/learn/go-beyond-the-numbers-translate-data-into-insight/lecture/kfl9b/find-stories-using-the-six-exploratory-data-analysis-practices).
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the function in the `pandas` library that allows you to get a specific number of rows from the top of a DataFrame.
#
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `head()` function from the `pandas` library.
#
# </details>

# %% [markdown]
# **Question:** What do you think the "Date Joined" column represents?

# %% [markdown]
#  [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# **Question:** What do you think the "Select Investors" column represents?

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# ### Assess the size of the dataset
#
# Get a sense of how large the dataset is. The `size` property that DataFrames have can help.

# %%
# How large the dataset is

### YOUR CODE HERE ###
companies.size
# Out:
# 10740

# %% [markdown]
# **Question:** What do you notice about the size of the dataset?

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# ### Determine the shape of the dataset
#
# Identify the number of rows and columns in the dataset. The `shape` property that DataFrames have can help.

# %%
# Shape of the dataset

### YOUR CODE HERE ###
companies.shape
# Out:
# (1074, 10)

# %% [markdown]
# **Question:** What do you notice about the shape of the dataset?

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# ### Get basic information about the dataset
#
# To further understand what the dataset entails, get basic information about the dataset, including the data type of values in each column. There is more than one way to approach this task. In this instance, use the `info()` function from `pandas`.

# %%
# Get information

### YOUR CODE HERE ###
companies.info
# Out:
# <bound method DataFrame.info of           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B      4/7/17          Artificial intelligence
# 1          SpaceX     $100B     12/1/12                            Other
# 2           SHEIN     $100B      7/3/18  E-commerce & direct-to-consumer
# 3          Stripe      $95B     1/23/14                          Fintech
# 4          Klarna      $46B    12/12/11                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B     6/29/17  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B     4/18/17  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B      5/6/21                Consumer & retail
# 1072         Zopa       $1B    10/19/21                          Fintech
# 1073        Zwift       $1B     9/16/20  E-commerce & direct-to-consumer
#
#                City  Country/Region      Continent  Year Founded Funding  \
# 0           Beijing           China           Asia          2012     $8B
# 1         Hawthorne   United States  North America          2002     $7B
# 2          Shenzhen           China           Asia          2008     $2B
# 3     San Francisco   United States  North America          2010     $2B
# 4         Stockholm          Sweden         Europe          2005     $4B
# ...             ...             ...            ...           ...     ...
# 1069       Shanghai           China           Asia          2012   $379M
# 1070        Beijing           China           Asia          2015   $990M
# 1071      Chongqing           China           Asia          2018    $80M
# 1072         London  United Kingdom         Europe          2005   $792M
# 1073     Long Beach   United States  North America          2014   $620M
#
#                                        Select Investors
# 0     Sequoia Capital China, SIG Asia Investments, S...
# 1     Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2     Tiger Global Management, Sequoia Capital China...
# 3           Khosla Ventures, LowercaseCapital, capitalG
# 4     Institutional Venture Partners, Sequoia Capita...
# ...                                                 ...
# 1069    K2 Ventures, Matrix Partners China, IDG Capital
# 1070                           58.com, Tencent Holdings
# 1071  Xingwang Investment Management, China Capital ...
# 1072  IAG Capital Partners, Augmentum Fintech, North...
# 1073    Novator Partners, True, Causeway Media Partners
#
# [1074 rows x 10 columns]>

# %% [markdown]
# **Question:** What do you notice about the type of data in the `Year Founded` column? Refer to the output from using `info()` above. Knowing the data type of this variable is helpful because it indicates what types of analysis can be done with that variable, how it can be aggregated with other variables, and so on.

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# **Question:** What do you notice about the type of data in the `Date Joined` column? Refer to the output from using `info()` above. Knowing the data type of this variable is helpful because it indicates what types of analysis can be done with that variable and how the variable can be transformed to suit specific tasks.

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# ## Step 3: Statistical tests

# %% [markdown]
# ### Find descriptive statistics
#
# Find descriptive statistics and structure your dataset. The `describe()` function from the `pandas` library can help. This function generates statistics for the numeric columns in a dataset.

# %%
# Get descriptive statistics

### YOUR CODE HERE ###
companies.describe()
# Out:
#        Year Founded
# count   1074.000000
# mean    2012.895717
# std        5.698573
# min     1919.000000
# 25%     2011.000000
# 50%     2014.000000
# 75%     2016.000000
# max     2021.000000

# %% [markdown]
# **Question:** Based on the table of descriptive stats generated above, what do you notice about the minimum value in the `Year Founded` column? This is important to know because it helps you understand how early the entries in the data begin.

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# **Question:** What do you notice about the maximum value in the `Year Founded` column? This is important to know because it helps you understand the most recent year captured by the data.

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# ### Convert the `Date Joined` column to datetime
#
# Use the `to_datetime()` function from the `pandas` library  to convert the `Date Joined` column to datetime. This splits each value into year, month, and date components. This is an important step in data cleaning, as it makes the data in this column easier to use in tasks you may encounter. To name a few examples, you may need to compare "date joined" between companies or determine how long it took a company to become a unicorn. Having "date joined" in datetime form would help you complete such tasks.

# %%
# Step 1: Use pd.to_datetime() to convert Date Joined column to datetime 
# Step 2: Update the column with the converted values

### YOUR CODE HERE ###
companies['Date_Joined'] =  pd.to_datetime(companies['Date_Joined'])

# %%
# Use .info() to confirm that the update actually took place

### YOUR CODE HERE ###
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
#  10  Date_Joined       1074 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 92.4+ KB

# %% [markdown]
# ### Create a `Year Joined` column
#
# It is common to encounter situations where you will need to compare the year joined with the year founded. The `Date Joined` column does not just have year—it has the year, month, and date. Extract the year component from the `Date Joined` column and add those year components into a new column to keep track of each company's year joined.

# %%
# Step 1: Use .dt.year to extract year component from Date Joined column
# Step 2: Add the result as a new column named Year Joined to the DataFrame

### YOUR CODE HERE ###
companies['Year Joined'] = companies['Date_Joined'].dt.year

# %%
# Use .head() to confirm that the new column did get added

### YOUR CODE HERE ###
companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B      4/7/17          Artificial intelligence
# 1     SpaceX     $100B     12/1/12                            Other
# 2      SHEIN     $100B      7/3/18  E-commerce & direct-to-consumer
# 3     Stripe      $95B     1/23/14                          Fintech
# 4     Klarna      $46B    12/12/11                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors Date_Joined  Year Joined
# 0  Sequoia Capital China, SIG Asia Investments, S...  2017-04-07         2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...  2012-12-01         2012
# 2  Tiger Global Management, Sequoia Capital China...  2018-07-03         2018
# 3        Khosla Ventures, LowercaseCapital, capitalG  2014-01-23         2014
# 4  Institutional Venture Partners, Sequoia Capita...  2011-12-12         2011

# %% [markdown]
# ## Step 4: Results and evaluation

# %% [markdown]
# ### Take a sample of the data
#
# It is not necessary to take a sample of the data in order to conduct the visualizations and EDA that follow. But you may encounter scenarios in the future where you will need to take a sample of the data due to time and resource limitations. For the purpose of developing your skills around sampling, take a sample of the data and work with that sample for the next steps of analysis you want to conduct. Use the `sample()` function for this task.
#
# - Use `sample()` with the `n` parameter set to `50` to randomly sample 50 unicorn companies from the data. Be sure to specify the `random_state` parameter to ensure reproducibility of your work. Save the result to a variable called `companies_sampled`.

# %%
# Sample the data

### YOUR CODE HERE ###
companies_sampled = companies.sample(n=50,random_state = 123)
companies_sampled
# Out:
#                          Company Valuation Date Joined  \
# 437                        ASAPP       $2B     5/19/21
# 209                     dbt Labs       $4B     6/30/21
# 816                     eSentire       $1B     2/22/22
# 1071                    Zihaiguo       $1B      5/6/21
# 643                       TUNGEE       $1B    12/15/21
# 529                       Jeeves       $2B     3/14/22
# 103                     Easyhome       $6B     2/12/18
# 929                    Haomao.AI       $1B    12/22/21
# 796                  Luoji Siwei       $1B     7/20/17
# 210       Globalization Partners       $4B     1/24/22
# 190                     Outreach       $4B     4/16/19
# 1073                       Zwift       $1B     9/16/20
# 684                   M1 Finance       $1B     7/14/21
# 261                Fetch Rewards       $3B     3/31/21
# 418                     Snapdocs       $2B     5/25/21
# 901                        Drata       $1B     11/8/21
# 822                   GlobalBees       $1B    12/28/21
# 664                       Earnix       $1B     2/21/21
# 704                         Papa       $1B     11/4/21
# 13                      Fanatics      $27B      6/6/12
# 558                  Divvy Homes       $2B     8/13/21
# 595   Trendy Group International       $2B     2/13/12
# 68                       Klaviyo       $9B    11/17/20
# 200            Redwood Materials       $4B     7/28/21
# 690               Clarify Health       $1B      4/5/22
# 244                       Upstox       $3B    11/29/21
# 899            Dental Monitoring       $1B    10/21/21
# 147                      Chipone       $5B    12/16/21
# 981                     NoBroker       $1B    11/23/21
# 444                      Exabeam       $2B      6/1/21
# 45                       Celonis      $11B     6/26/18
# 252                  MessageBird       $3B     10/8/20
# 624                 Juma Peisong       $1B    11/26/18
# 273                         Oura       $3B      4/5/22
# 678                      Yijiupi       $1B     9/20/18
# 956           LinkDoc Technology       $1B      7/5/18
# 547                     Aviatrix       $2B      9/8/21
# 896                   CommerceIQ       $1B     3/21/22
# 724                         RIDI       $1B     1/24/22
# 730                   Betterment       $1B     9/29/21
# 309                        Skims       $3B      4/9/21
# 388                   Tradeshift       $2B     5/30/18
# 838                         Nxin       $1B     9/18/18
# 1053                        Veev       $1B     2/24/22
# 1010             REEF Technology       $1B    12/10/18
# 1027                  SmartAsset       $1B     6/24/21
# 623                      JimuBox       $1B     4/21/15
# 1035                      Stytch       $1B    11/18/21
# 921                      FXiaoKe       $1B      7/2/15
# 906                      EcoFlow       $1B     6/10/21
#
#                                  Industry           City Country/Region  \
# 437               Artificial intelligence       New York  United States
# 209           Data management & analytics   Philadelphia  United States
# 816                         Cybersecurity       Waterloo         Canada
# 1071                    Consumer & retail      Chongqing          China
# 643               Artificial Intelligence      Guangzhou          China
# 529                               Fintech        Orlando  United States
# 103                     Consumer & retail        Beijing          China
# 929               Artificial Intelligence        Beijing          China
# 796                                Edtech        Beijing          China
# 210          Internet software & services         Boston  United States
# 190          Internet software & services        Seattle  United States
# 1073      E-commerce & direct-to-consumer     Long Beach  United States
# 684                               Fintech        Chicago  United States
# 261       E-commerce & direct-to-consumer        Madison  United States
# 418                               Fintech  San Francisco  United States
# 901                         Cybersecurity      San Diego  United States
# 822       E-commerce & direct-to-consumer      New Delhi          India
# 664                               Fintech     Giv'atayim         Israel
# 704                                Health          Miami  United States
# 13        E-commerce & direct-to-consumer   Jacksonville  United States
# 558                               Fintech  San Francisco  United States
# 595                     Consumer & retail        Kowloon      Hong Kong
# 68           Internet software & services         Boston  United States
# 200                                 Other    Carson City  United States
# 690                                Health  San Francisco  United States
# 244                               Fintech         Mumbai          India
# 899                                Health          Paris         France
# 147                              Hardware        Beijing          China
# 981          Internet software & services      Bengaluru          India
# 444                         Cybersecurity    Foster City  United States
# 45            Data management & analytics         Munich        Germany
# 252           Mobile & telecommunications      Amsterdam    Netherlands
# 624   Supply chain, logistics, & delivery        Chengdu          China
# 273                                Health           Oulu        Finland
# 678                     Consumer & retail        Beijing          China
# 956                                Health        Beijing          China
# 547          Internet software & services    Santa Clara  United States
# 896               Artificial Intelligence      Palo Alto  United States
# 724       E-commerce & direct-to-consumer          Seoul    South Korea
# 730                               Fintech       New York  United States
# 309       E-commerce & direct-to-consumer    Los Angeles  United States
# 388                               Fintech  San Francisco  United States
# 838          Internet software & services        Beijing          China
# 1053         Internet software & services      San Mateo  United States
# 1010  Supply chain, logistics, & delivery          Miami  United States
# 1027                              Fintech       New York  United States
# 623                               Fintech        Beijing          China
# 1035                        Cybersecurity  San Francisco  United States
# 921           Mobile & telecommunications        Beijing          China
# 906                              Hardware       Shenzhen          China
#
#           Continent  Year Founded Funding  \
# 437   North America          2014   $380M
# 209   North America          2016   $414M
# 816   North America          2001   $186M
# 1071           Asia          2018    $80M
# 643            Asia          2016   $171M
# 529   North America          2019   $268M
# 103            Asia          1999     $2B
# 929            Asia          2019   $157M
# 796            Asia          2012   $144M
# 210   North America          2012   $350M
# 190   North America          2011   $489M
# 1073  North America          2014   $620M
# 684   North America          2015   $323M
# 261   North America          2014   $582M
# 418   North America          2012   $253M
# 901   North America          2020   $128M
# 822            Asia          2021   $185M
# 664            Asia          2001    $98M
# 704   North America          2016   $241M
# 13    North America          2002     $4B
# 558   North America          2017   $370M
# 595            Asia          1999   $200M
# 68    North America          2012   $679M
# 200   North America          2017   $792M
# 690   North America          2015   $328M
# 244            Asia          2010    $54M
# 899          Europe          2014   $232M
# 147            Asia          2008     $1B
# 981            Asia          2014   $424M
# 444   North America          2013   $390M
# 45           Europe          2011     $1B
# 252          Europe          2011     $1B
# 624            Asia          2011   $281M
# 273          Europe          2013   $148M
# 678            Asia          2014   $511M
# 956            Asia          2014   $253M
# 547   North America          2014   $341M
# 896   North America          2012   $196M
# 724            Asia          2008   $178M
# 730   North America          2010   $335M
# 309   North America          2019   $399M
# 388   North America          2009   $861M
# 838            Asia          2015    $53M
# 1053  North America          2008   $585M
# 1010  North America          2015     $2B
# 1027  North America          2012   $161M
# 623            Asia          2013   $131M
# 1035  North America          2020   $126M
# 921            Asia          2011   $283M
# 906            Asia          2017   $105M
#
#                                        Select Investors Date_Joined  \
# 437   March Capital Partners, HOF Capital, Emergence...  2021-05-19
# 209   Andreessen Horowitz, Amplify Partners, Sequoia...  2021-06-30
# 816     Edison Partners, Georgian Partners, VentureLink  2022-02-22
# 1071  Xingwang Investment Management, China Capital ...  2021-05-06
# 643   UNITY VENTURES, Qiming Venture Partners, GGV C...  2021-12-15
# 529   Tencent Holdings, CRV, Clocktower Technology V...  2022-03-14
# 103          Alibaba Group, Boyu Capital, Borui Capital  2018-02-12
# 929   Qualcomm Ventures, Nine Intelligence Capital, ...  2021-12-22
# 796   Sequoia Capital China, Qiming Venture Partners...  2017-07-20
# 210         Vista Equity Partners, Wincove, TDR Capital  2022-01-24
# 190                Mayfield Fund, M12, Trinity Ventures  2019-04-16
# 1073    Novator Partners, True, Causeway Media Partners  2020-09-16
# 684   Left Lane Capital, Clocktower Technology Ventu...  2021-07-14
# 261                     Greycroft, Loeb.NYC, DST Global  2021-03-31
# 418      Sequoia Capital, Y Combinator, F-Prime Capital  2021-05-25
# 901          Cowboy Ventures, Leaders Fund, GGV Capital  2021-11-08
# 822   Chiratae Ventures, SoftBank Group, Trifecta Ca...  2021-12-28
# 664   Jerusalem Venture Partners, Israel Growth Part...  2021-02-21
# 704   Initialized Capital, Canaan Partners, Sound Ve...  2021-11-04
# 13    SoftBank Group, Andreessen Horowitz, Temasek H...  2012-06-06
# 558   Andreessen Horowitz, Caffeinated Capital, SciF...  2021-08-13
# 595                                  L Capital Partners  2012-02-13
# 68               Summit Partners, Accel, Astral Capital  2020-11-17
# 200   Breakthrough Energy Ventures, Capricorn Invest...  2021-07-28
# 690              KKR, Aspenwood Ventures, Spark Capital  2022-04-05
# 244            Tiger Global Management, Kalaari Capital  2021-11-29
# 899   Vitruvian Partners, Merieux Equity Partners, S...  2021-10-21
# 147   China Grand Prosperity Investment, Silk Road H...  2021-12-16
# 981        General Atlantic, Elevation Capital, BEENEXT  2021-11-23
# 444   Norwest Venture Partners, Aspect Ventures, Lig...  2021-06-01
# 45                                       Accel, 83North  2018-06-26
# 252                        Y Combinator, Atomico, Accel  2020-10-08
# 624   Ding Xiang Capital, New Hope Fund, Sino-Ocean ...  2018-11-26
# 273   Forerunner Ventures, Lifeline Ventures, MSD Ca...  2022-04-05
# 678   Source Code Capital, Meituan Dianping, Tencent...  2018-09-20
# 956   China Investment Corporation, New Enterprise A...  2018-07-05
# 547                 Ignition Partners, Formation 8, CRV  2021-09-08
# 896   Trinity Ventures, Madrona Venture Group, Shast...  2022-03-21
# 724          Atinum Investment, Company K Partners, GIC  2022-01-24
# 730   Bessemer Venture Partners, Menlo Ventures, Ant...  2021-09-29
# 309   Thrive Capital, Alliance Consumer Growth, Imag...  2021-04-09
# 388     Notion Capital, Scentan Ventures, Kite Ventures  2018-05-30
# 838   Beijing Juneng Hesheng Industry Investment Fun...  2018-09-18
# 1053           Zeev Ventures, Bond, Fifth Wall Ventures  2022-02-24
# 1010  Target Global, UBS Asset Management, Mubadala ...  2018-12-10
# 1027  Javelin Venture Partners, TTV Capital, Peterso...  2021-06-24
# 623   Matrix Partners China, Ventech China, Shunwei ...  2015-04-21
# 1035          Index Ventures, Benchmark, Thrive Capital  2021-11-18
# 921   IDG Capital, Northern Light Venture Capital, D...  2015-07-02
# 906   Delian Capital, China International Capital Co...  2021-06-10
#
#       Year Joined
# 437          2021
# 209          2021
# 816          2022
# 1071         2021
# 643          2021
# 529          2022
# 103          2018
# 929          2021
# 796          2017
# 210          2022
# 190          2019
# 1073         2020
# 684          2021
# 261          2021
# 418          2021
# 901          2021
# 822          2021
# 664          2021
# 704          2021
# 13           2012
# 558          2021
# 595          2012
# 68           2020
# 200          2021
# 690          2022
# 244          2021
# 899          2021
# 147          2021
# 981          2021
# 444          2021
# 45           2018
# 252          2020
# 624          2018
# 273          2022
# 678          2018
# 956          2018
# 547          2021
# 896          2022
# 724          2022
# 730          2021
# 309          2021
# 388          2018
# 838          2018
# 1053         2022
# 1010         2018
# 1027         2021
# 623          2015
# 1035         2021
# 921          2015
# 906          2021

# %% [markdown]
# ### Visualize the time it took companies to reach unicorn status
#
# Visualize the longest time it took companies to reach unicorn status for each industry represented in the sample. To create a bar plot to visualize this, use the `bar()` function from the `matplotlib.pyplot` module. You'll first need to prepare the data.

# %%
# Prepare data for plotting

### YOUR CODE HERE ###
plt.bar(x=companies_sampled['Industry'], height=companies_sampled['Year Joined'] - companies_sampled['Year Founded'])
plt.title("Years to achieve unicorn status per industry")
plt.xlabel('Industries')
plt.ylabel('Years')
plt.xticks(rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 1</strong></h4></summary>
#
# To prepare the data for modeling, begin by creating a column that represents the number of years it took each company to reach unicorn status.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 2</strong></h4></summary>
#
# To prepare the data for modeling, group the dataframe by industry and get the maximum value in the newly created column for each industry.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 3</strong></h4></summary>
#
# You can use the `plt.bar()` to create the bar plot, passing in the categories and heights of the bars.
#
# You can use `plt.title()`, `plt.xlabel()`, and `plt.ylabel()` to set the title, x-axis label, and y-axis label, respectively.
#
# You can use `plt.xticks()` to rotate labels on the x-axis of a plot. The parameters `rotation=45, horizontalalignment='right'` can be passed in to rotate the labels by 45 degrees and align the labels to the right.
#
# You can use `plt.show()` to display a plot.
#
# </details>

# %% [markdown]
# **Question:** What do you observe from this bar plot?

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# ### Visualize the maximum unicorn company valuation per industry
#
# Visualize unicorn companies' maximum valuation for each industry represented in the sample. To create a bar plot to visualize this, use the `bar()` function from the `matplotlib.pyplot` module. Before plotting, create a new column that represents the companies' valuations as numbers (instead of strings, as they're currently represented). Then, use this new column to plot your data.

# %%
# Create a column representing company valuation as numeric data
companies_sampled['valuation (in billions)'] = companies['Valuation']
companies_sampled['valuation (in billions)'] = companies_sampled['valuation (in billions)'].str.replace('$','')
companies_sampled['valuation (in billions)'] = companies_sampled['valuation (in billions)'].str.replace('B','')
companies_sampled['valuation (in billions)'] = companies_sampled['valuation (in billions)'].astype('int')
companies_sampled.head(20)
# Out:
#                      Company Valuation Date Joined  \
# 437                    ASAPP       $2B     5/19/21
# 209                 dbt Labs       $4B     6/30/21
# 816                 eSentire       $1B     2/22/22
# 1071                Zihaiguo       $1B      5/6/21
# 643                   TUNGEE       $1B    12/15/21
# 529                   Jeeves       $2B     3/14/22
# 103                 Easyhome       $6B     2/12/18
# 929                Haomao.AI       $1B    12/22/21
# 796              Luoji Siwei       $1B     7/20/17
# 210   Globalization Partners       $4B     1/24/22
# 190                 Outreach       $4B     4/16/19
# 1073                   Zwift       $1B     9/16/20
# 684               M1 Finance       $1B     7/14/21
# 261            Fetch Rewards       $3B     3/31/21
# 418                 Snapdocs       $2B     5/25/21
# 901                    Drata       $1B     11/8/21
# 822               GlobalBees       $1B    12/28/21
# 664                   Earnix       $1B     2/21/21
# 704                     Papa       $1B     11/4/21
# 13                  Fanatics      $27B      6/6/12
#
#                              Industry           City Country/Region  \
# 437           Artificial intelligence       New York  United States
# 209       Data management & analytics   Philadelphia  United States
# 816                     Cybersecurity       Waterloo         Canada
# 1071                Consumer & retail      Chongqing          China
# 643           Artificial Intelligence      Guangzhou          China
# 529                           Fintech        Orlando  United States
# 103                 Consumer & retail        Beijing          China
# 929           Artificial Intelligence        Beijing          China
# 796                            Edtech        Beijing          China
# 210      Internet software & services         Boston  United States
# 190      Internet software & services        Seattle  United States
# 1073  E-commerce & direct-to-consumer     Long Beach  United States
# 684                           Fintech        Chicago  United States
# 261   E-commerce & direct-to-consumer        Madison  United States
# 418                           Fintech  San Francisco  United States
# 901                     Cybersecurity      San Diego  United States
# 822   E-commerce & direct-to-consumer      New Delhi          India
# 664                           Fintech     Giv'atayim         Israel
# 704                            Health          Miami  United States
# 13    E-commerce & direct-to-consumer   Jacksonville  United States
#
#           Continent  Year Founded Funding  \
# 437   North America          2014   $380M
# 209   North America          2016   $414M
# 816   North America          2001   $186M
# 1071           Asia          2018    $80M
# 643            Asia          2016   $171M
# 529   North America          2019   $268M
# 103            Asia          1999     $2B
# 929            Asia          2019   $157M
# 796            Asia          2012   $144M
# 210   North America          2012   $350M
# 190   North America          2011   $489M
# 1073  North America          2014   $620M
# 684   North America          2015   $323M
# 261   North America          2014   $582M
# 418   North America          2012   $253M
# 901   North America          2020   $128M
# 822            Asia          2021   $185M
# 664            Asia          2001    $98M
# 704   North America          2016   $241M
# 13    North America          2002     $4B
#
#                                        Select Investors Date_Joined  \
# 437   March Capital Partners, HOF Capital, Emergence...  2021-05-19
# 209   Andreessen Horowitz, Amplify Partners, Sequoia...  2021-06-30
# 816     Edison Partners, Georgian Partners, VentureLink  2022-02-22
# 1071  Xingwang Investment Management, China Capital ...  2021-05-06
# 643   UNITY VENTURES, Qiming Venture Partners, GGV C...  2021-12-15
# 529   Tencent Holdings, CRV, Clocktower Technology V...  2022-03-14
# 103          Alibaba Group, Boyu Capital, Borui Capital  2018-02-12
# 929   Qualcomm Ventures, Nine Intelligence Capital, ...  2021-12-22
# 796   Sequoia Capital China, Qiming Venture Partners...  2017-07-20
# 210         Vista Equity Partners, Wincove, TDR Capital  2022-01-24
# 190                Mayfield Fund, M12, Trinity Ventures  2019-04-16
# 1073    Novator Partners, True, Causeway Media Partners  2020-09-16
# 684   Left Lane Capital, Clocktower Technology Ventu...  2021-07-14
# 261                     Greycroft, Loeb.NYC, DST Global  2021-03-31
# 418      Sequoia Capital, Y Combinator, F-Prime Capital  2021-05-25
# 901          Cowboy Ventures, Leaders Fund, GGV Capital  2021-11-08
# 822   Chiratae Ventures, SoftBank Group, Trifecta Ca...  2021-12-28
# 664   Jerusalem Venture Partners, Israel Growth Part...  2021-02-21
# 704   Initialized Capital, Canaan Partners, Sound Ve...  2021-11-04
# 13    SoftBank Group, Andreessen Horowitz, Temasek H...  2012-06-06
#
#       Year Joined  valuation (in billions)
# 437          2021                        2
# 209          2021                        4
# 816          2022                        1
# 1071         2021                        1
# 643          2021                        1
# 529          2022                        2
# 103          2018                        6
# 929          2021                        1
# 796          2017                        1
# 210          2022                        4
# 190          2019                        4
# 1073         2020                        1
# 684          2021                        1
# 261          2021                        3
# 418          2021                        2
# 901          2021                        1
# 822          2021                        1
# 664          2021                        1
# 704          2021                        1
# 13           2012                       27

# %%
# Create bar plot
# with the various industries as the categories of the bars
# and the maximum valuation for each industry as the height of the bars
plt.bar(x=companies_sampled['Industry'], height=companies_sampled['valuation (in billions)'])
plt.title("Valuation per industry")
plt.xlabel('Industries')
plt.ylabel('valuation (in billions)')
plt.xticks(rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Repeat the process from the last task, only this time with different variables.
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the function in the `matplotlib.pyplot` module that allows you to create a bar plot, specifying the category and height for each bar.
#
# Use the functions in the `matplotlib.pyplot` module that allow you to set the title, x-axis label, and y-axis label of plots. In that module, there are also functions for rotating the labels on the x-axis and displaying the plot.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `plt.bar()` to create the bar plot, passing in the categories and heights of the bars.
#
# Use `plt.title()`, `plt.xlabel()`, and `plt.ylabel()` to set the title, x-axis label, and y-axis label, respectively.
#
# Use `plt.xticks()` to rotate labels on the x-axis of a plot. The parameters `rotation=45, horizontalalignment='right'` can be passed in to rotate the labels by 45 degrees and align the labels to the right.
#
# Use `plt.show()` to display a plot.
#
# </details>

# %% [markdown]
# **Question:** What do you observe from this bar plot?

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# ## Considerations

# %% [markdown]
# **What are some key takeaways that you learned from this lab?**

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# **What findings would you share with others?**

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# **What recommendations would you share with stakeholders based on these findings?**

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# **References**
#
# Bhat, M.A. (2022, March). [*Unicorn Companies*](https://www.kaggle.com/datasets/mysarahmadbhat/unicorn-companies).
