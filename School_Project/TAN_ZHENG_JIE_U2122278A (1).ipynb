# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
QuizData = pd.read_csv('quizData_SetE.csv')
QuizData.head()
# Out:
#    Height  Weight  Diameter Price
# 0   0.010  0.0015     0.055   Low
# 1   0.025  0.0050     0.100   Low
# 2   0.030  0.0040     0.100   Low
# 3   0.030  0.0030     0.090   Low
# 4   0.030  0.0050     0.120   Low

# %%
#problem 1
QuizData.describe()
# Out:
#             Height       Weight     Diameter
# count  4000.000000  4000.000000  4000.000000
# mean      0.138874     0.236674     0.406095
# std       0.042092     0.139511     0.099668
# min       0.000000     0.001500     0.055000
# 25%       0.110000     0.125375     0.345000
# 50%       0.140000     0.229500     0.420000
# 75%       0.165000     0.325000     0.480000
# max       1.130000     1.005000     0.650000

# %%
Height = pd.DataFrame(QuizData['Height'])
Weight = pd.DataFrame(QuizData['Weight'])
Diameter = pd.DataFrame(QuizData['Diameter'])
Price = pd.DataFrame(QuizData['Price'])

# %%
f, axes = plt.subplots(3, 3, figsize=(24, 12))

sb.boxplot(Height, orient = "h", ax = axes[0,0])
sb.histplot(Height, kde = False, ax = axes[0,1])
sb.violinplot(Height, ax = axes[0,2])


sb.boxplot(Weight, orient = "h", ax = axes[1,0], color = 'g')
sb.histplot(Weight, kde = False, ax = axes[1,1], color = 'g')
sb.violinplot(Weight, ax = axes[1,2], color = 'g')


sb.boxplot(Diameter, orient = "h", ax = axes[2,0], color = 'r')
sb.histplot(Diameter, kde = False, ax = axes[2,1], color = 'r')
sb.violinplot(Diameter, ax = axes[2,2], color = 'r')
# Out:
# <AxesSubplot:>

# %%
#According to the statistical plots, it is weight that has the most amount of outliers.

# %%
sb.catplot(y = 'Price', data = QuizData, kind = "count")
QuizData['Price'].describe()
# Out:
# count     4000
# unique       2
# top        Low
# freq      2623
# Name: Price, dtype: object

# %%
f, axes = plt.subplots(1, 1, figsize=(16, 8))
sb.boxplot(x = 'Height', y = 'Price', data = QuizData)

f, axes = plt.subplots(1, 1, figsize=(16, 8))
sb.boxplot(x = 'Weight', y = 'Price', data = QuizData)

f, axes = plt.subplots(1, 1, figsize=(16, 8))
sb.boxplot(x = 'Diameter', y = 'Price', data = QuizData)
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Price'>

# %%
#According to the boxplots, Diameter is the most important in predicting the price. Lesser outliers compare to weight and have a better quartile median result compared to Height.

# %%
#Problem 2
# Import Decision Tree Classifier model from Scikit-Learn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 2)

# %%
#First uni-variate: Price against Height
# Extract Response and Predictors
y = pd.DataFrame(QuizData['Price'])
X = pd.DataFrame(QuizData['Height'])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# Train the Decision Tree Classifier model
dectree.fit(X_train, y_train)

from sklearn.tree import plot_tree
fig, ax = plt.subplots(figsize=(12, 12))
out = plot_tree(dectree, 
          feature_names = X_train.columns,
          class_names = [str(x) for x in dectree.classes_],
          filled=True)

for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor('black')
        arrow.set_linewidth(3)
        
plt.show()

# Predict the Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)

# Print the Classification Accuracy
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
# Out:
# Classification Accuracy 	: 0.7225

# %%
#Second uni-variate: Price against Weight
# Extract Response and Predictors
y = pd.DataFrame(QuizData['Price'])
X = pd.DataFrame(QuizData['Weight'])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# Train the Decision Tree Classifier model
dectree.fit(X_train, y_train)

from sklearn.tree import plot_tree
fig, ax = plt.subplots(figsize=(12, 12))
out = plot_tree(dectree, 
          feature_names = X_train.columns,
          class_names = [str(x) for x in dectree.classes_],
          filled=True)

for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor('black')
        arrow.set_linewidth(3)
        
plt.show()

# Predict the Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)

# Print the Classification Accuracy
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
# Out:
# Classification Accuracy 	: 0.7271428571428571

# %%
#Third uni-variate: Price against Diameter
# Extract Response and Predictors
y = pd.DataFrame(QuizData['Price'])
X = pd.DataFrame(QuizData['Diameter'])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# Train the Decision Tree Classifier model
dectree.fit(X_train, y_train)

from sklearn.tree import plot_tree
fig, ax = plt.subplots(figsize=(12, 12))
out = plot_tree(dectree, 
          feature_names = X_train.columns,
          class_names = [str(x) for x in dectree.classes_],
          filled=True)

for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor('black')
        arrow.set_linewidth(3)
        
plt.show()

# Predict the Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)

# Print the Classification Accuracy
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
# Out:
# Classification Accuracy 	: 0.7232142857142857

# %%
#Price to height
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Extract Response and Predictors
y = pd.DataFrame(QuizData['Price'])
X = pd.DataFrame(QuizData['Height'])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# Decision Tree using Train Data
dectree = DecisionTreeClassifier(max_depth = 2)  # create the decision tree object
dectree.fit(X_train, y_train)                    # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
        
plt.show()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7432142857142857
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.6933333333333334

# %%
#Price to weight
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Extract Response and Predictors
y = pd.DataFrame(QuizData['Price'])
X = pd.DataFrame(QuizData['Weight'])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# Decision Tree using Train Data
dectree = DecisionTreeClassifier(max_depth = 2)  # create the decision tree object
dectree.fit(X_train, y_train)                    # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
        
plt.show()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7235714285714285
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.7358333333333333

# %%
#Price to diameter
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Extract Response and Predictors
y = pd.DataFrame(QuizData['Price'])
X = pd.DataFrame(QuizData['Diameter'])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# Decision Tree using Train Data
dectree = DecisionTreeClassifier(max_depth = 2)  # create the decision tree object
dectree.fit(X_train, y_train)                    # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
        
plt.show()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7217857142857143
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.7133333333333334

# %%
#According to the confusion matrix,weight is the best variable to predict price as it has the most reliable classification accuracy for test and train dataset compared to others.

# %%
#problem 3
#single multi-variate price against all three components
# Extract Response and Predictors
y = pd.DataFrame(QuizData['Price'])
X = pd.DataFrame(QuizData[['Height' , 'Weight', 'Diameter']])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# Train the Decision Tree Classifier model
dectree.fit(X_train, y_train)

from sklearn.tree import plot_tree
fig, ax = plt.subplots(figsize=(12, 12))
out = plot_tree(dectree, 
          feature_names = X_train.columns,
          class_names = [str(x) for x in dectree.classes_],
          filled=True)

for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor('black')
        arrow.set_linewidth(3)
        
plt.show()

# %%
# Predict Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7271428571428571
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.7116666666666667

# %%
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Decision Tree using same Train Data
dectree = DecisionTreeClassifier(max_depth = 20)  # create the decision tree object
dectree.fit(X_train, y_train)                    # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

# Plot the Decision Tree
from sklearn.tree import plot_tree
fig, ax = plt.subplots(figsize=(48, 6))
out = plot_tree(dectree, 
          feature_names = X_train.columns,
          class_names = [str(x) for x in dectree.classes_],
          filled=True)

for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor('black')
        arrow.set_linewidth(3)
        
plt.show()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.975
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.71

# %%
#According the the classification accuracy, the train dataset has an excellent result of accuracy but lackluster in the test dataset, even lower than the model in 3a). 
#thus my opinion is, it might not be a better model than 3a.

# %%
# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Extract Response and Predictors
predictors = ['Height' , 'Weight', 'Diameter']

y = pd.DataFrame(QuizData["Price"])
X = pd.DataFrame(QuizData[predictors])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# Decision Tree using Train Data
dectree = DecisionTreeClassifier(max_depth = 6)  # create the decision tree object
dectree.fit(X_train, y_train)                    # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
        
plt.show()

# Plot the Decision Tree
from sklearn.tree import plot_tree
fig, ax = plt.subplots(figsize=(48, 6))
out = plot_tree(dectree, 
          feature_names = X_train.columns,
          class_names = [str(x) for x in dectree.classes_],
          filled=True)

for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor('black')
        arrow.set_linewidth(3)
        
plt.show()

#results to compare: this is my original accuracy
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7271428571428571

# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.7116666666666667
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7884375
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.74875

# %%
#To improve my decision tree model, i set max depth to 6 and test size to 20%. An improvement from 0.7116 to 0.74875 for test dataset and 0.727 to 0.788 for train dataset.
